# %% [markdown]
# # Edge Detection

# %% [markdown]
# Edge detection includes a variety of mathematical methods that aim at identifying edges, curves in a digital image at which the image brightness changes sharply or, more formally, has discontinuities. The same problem of finding discontinuities in one-dimensional signals is known as step detection and the problem of finding signal discontinuities over time is known as change detection. Edge detection is a fundamental tool in image processing, machine vision and computer vision, particularly in the areas of feature detection and feature extraction. [ Source](https://en.wikipedia.org/wiki/Edge_detection)

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
image = plt.imread('/content/drive/MyDrive/ComputerVision/car.jpg')
plt.imshow(image)

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(gray_image)

# %% [markdown]
# ## Soble
#
# Sobel Edge detection is a widely used algorithm of edge detection in image processing.  Sobel is one of the most popular edge detection algorithms used in today's technology.
#
# **How it works :**
# When using a Sobel Edge Detector, it is first best to convert the image from an RGB scale to a Grayscale image. Then from there, we will use what is called kernel convolution. A kernel is a 3 x 3 matrix consisting of differently (or symmetrically) weighted indexes. This will represent the filter that we will be implementing for an edge detection.
#
# When we want to scan across the X direction of an image for example, we will want to use the following X Direction Kernel to scan for large changes in the gradient. Similarly, when we want to scan across the Y direction of an image, we could also use the following Y Direction Kernel to scan for large gradients as well. [Source](https://www.projectrhea.org/rhea/index.php/An_Implementation_of_Sobel_Edge_Detection#:~:text=in%20today's%20technology.-,The%20Math%20Behind%20the%20Algorithm,be%20processed%20separately%20as%20well.)

# %%
x_sobel = cv2.Sobel(gray_image, cv2.CV_64F, 0, 1, ksize = 7)
plt.imshow(x_sobel)
plt.title("X sobel Edge Detection")
# Out:
# Text(0.5, 1.0, 'X sobel Edge Detection')

# %%
y_sobel = cv2.Sobel(gray_image, cv2.CV_64F, 1, 0, ksize = 7)
plt.imshow(y_sobel)
plt.title("Y sobel Edge Detection")
# Out:
# Text(0.5, 1.0, 'Y sobel Edge Detection')

# %% [markdown]
# ## Laplacian
#
# **How it works :**
# You can refer this document to understand the Algorithm.
# [Source](https://www.owlnet.rice.edu/~elec539/Projects97/morphjrks/laplacian.html)

# %%
laplacian = cv2.Laplacian(gray_image, cv2.CV_64F)

plt.imshow(laplacian)
plt.title("Laplcian Edge Detection")
# Out:
# Text(0.5, 1.0, 'Laplcian Edge Detection')

# %% [markdown]
# ## Canny
# The Canny edge detector is an edge detection operator that uses a multi-stage algorithm to detect a wide range of edges in images. It was developed by John F. Canny in 1986. Canny also produced a computational theory of edge detection explaining why the technique works. [Source](https://en.wikipedia.org/wiki/Canny_edge_detector)
#
# **parameter :**
#
# **threshold_1** : first threshold for the hysteresis procedure
#
# **threshold_2** : second threshold for the hysteresis procedure

# %%
threshold_1 = 120
threshold_2 = 200

canny = cv2.Canny(gray_image, threshold_1, threshold_2)
plt.imshow(canny)
plt.title("Canny Edge Detection")
# Out:
# Text(0.5, 1.0, 'Canny Edge Detection')
