# %%
import cv2
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image_color = mpimg.imread("/content/Find_Truck_color.jpg")

# %%
height, width = image_color.shape[:2]

# %% [markdown]
# # Draw rectangle around the truck

# %%
top_left = (620, 150)
bottom_right = (810, 250)
cv2.rectangle(image_color, top_left, bottom_right, (0, 0, 255), 5)
# Out:
# array([[[170, 185, 204],
#         [172, 187, 206],
#         [175, 190, 209],
#         ...,
#         [209, 210, 214],
#         [209, 210, 214],
#         [209, 210, 212]],
#
#        [[181, 196, 215],
#         [181, 198, 216],
#         [183, 200, 218],
#         ...,
#         [209, 210, 214],
#         [210, 211, 215],
#         [210, 211, 213]],
#
#        [[182, 199, 219],
#         [182, 199, 217],
#         [183, 200, 218],
#         ...,
#         [210, 211, 215],
#         [211, 212, 216],
#         [211, 212, 214]],
#
#        ...,
#
#        [[ 26,  31,  34],
#         [ 26,  31,  34],
#         [ 26,  31,  34],
#         ...,
#         [  1,   1,   1],
#         [  1,   1,   1],
#         [  1,   1,   1]],
#
#        [[ 25,  30,  33],
#         [ 25,  30,  33],
#         [ 25,  30,  33],
#         ...,
#         [  1,   1,   1],
#         [  0,   0,   0],
#         [  0,   0,   0]],
#
#        [[ 24,  29,  32],
#         [ 24,  29,  32],
#         [ 23,  28,  31],
#         ...,
#         [  0,   0,   0],
#         [  0,   0,   0],
#         [  0,   0,   0]]], dtype=uint8)

# %%
plt.imshow(image_color)
